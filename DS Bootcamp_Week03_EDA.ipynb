# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://data.cityofnewyork.us/api/views/6fi9-q3ta/rows.csv?accessType=DOWNLOAD'
bridge_df = pd.read_csv(url)

# %%
bridge_df
# Out:
#                hour_beginning         location  Pedestrians  \
# 0      04/30/2019 12:00:00 AM  Brooklyn Bridge            3
# 1      12/31/2019 10:00:00 PM  Brooklyn Bridge           10
# 2      12/31/2019 11:00:00 PM  Brooklyn Bridge            2
# 3      12/31/2019 09:00:00 PM  Brooklyn Bridge           12
# 4      04/01/2019 03:00:00 AM  Brooklyn Bridge            1
# ...                       ...              ...          ...
# 16052  06/22/2018 04:00:00 AM  Brooklyn Bridge            7
# 16053  07/19/2018 06:00:00 AM  Brooklyn Bridge          192
# 16054  06/16/2018 04:00:00 PM  Brooklyn Bridge         2623
# 16055  07/24/2018 06:00:00 PM  Brooklyn Bridge         2016
# 16056  07/23/2018 12:00:00 AM  Brooklyn Bridge           57
#
#        Towards Manhattan  Towards Brooklyn      weather_summary  temperature  \
# 0                      3                 0                  NaN          NaN
# 1                      9                 1               cloudy         42.0
# ...

# %%
bridge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16057 entries, 0 to 16056
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hour_beginning     16057 non-null  object
#  1   location           16057 non-null  object
#  2   Pedestrians        16057 non-null  int64
#  3   Towards Manhattan  16057 non-null  int64
#  4   Towards Brooklyn   16057 non-null  int64
#  5   weather_summary    16041 non-null  object
#  6   temperature        16041 non-null  float64
#  7   precipitation      16041 non-null  float64
#  8   lat                16057 non-null  float64
#  9   long               16057 non-null  float64
#  10  events             1124 non-null   object
#  11  Location1          16057 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.5+ MB

# %%
bridge_df['hour_beginning'] = pd.to_datetime(bridge_df['hour_beginning'])

# %%
bridge_df.head()
# Out:
#        hour_beginning         location  Pedestrians  Towards Manhattan  \
# 0 2019-04-30 00:00:00  Brooklyn Bridge            3                  3
# 1 2019-12-31 22:00:00  Brooklyn Bridge           10                  9
# 2 2019-12-31 23:00:00  Brooklyn Bridge            2                  0
# 3 2019-12-31 21:00:00  Brooklyn Bridge           12                  0
# 4 2019-04-01 03:00:00  Brooklyn Bridge            1                  0
#
#    Towards Brooklyn weather_summary  temperature  precipitation        lat  \
# 0                 0             NaN          NaN            NaN  40.708164
# 1                 1          cloudy         42.0         0.0005  40.708164
# 2                 2          cloudy         42.0         0.0004  40.708164
# 3                12          cloudy         42.0         0.0036  40.708164
# 4                 1     clear-night         36.0         0.0000  40.708164
#
#         long events                              Location1
# ...

# %%
bridge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16057 entries, 0 to 16056
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hour_beginning     16057 non-null  datetime64[ns]
#  1   location           16057 non-null  object
#  2   Pedestrians        16057 non-null  int64
#  3   Towards Manhattan  16057 non-null  int64
#  4   Towards Brooklyn   16057 non-null  int64
#  5   weather_summary    16041 non-null  object
#  6   temperature        16041 non-null  float64
#  7   precipitation      16041 non-null  float64
#  8   lat                16057 non-null  float64
#  9   long               16057 non-null  float64
#  10  events             1124 non-null   object
#  11  Location1          16057 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
bridge_df.sample(5)
# Out:
#            hour_beginning         location  Pedestrians  Towards Manhattan  \
# 11257 2017-11-10 01:00:00  Brooklyn Bridge           16                  9
# 13006 2018-05-22 08:00:00  Brooklyn Bridge          425                154
# 2763  2019-06-24 16:00:00  Brooklyn Bridge         1909                946
# 4848  2019-01-30 08:00:00  Brooklyn Bridge          152                 50
# 4059  2019-12-16 01:00:00  Brooklyn Bridge            0                  0
#
#        Towards Brooklyn      weather_summary  temperature  precipitation  \
# 11257                 7  partly-cloudy-night         49.0         0.0021
# 13006               271    partly-cloudy-day         62.0         0.0000
# 2763                963            clear-day         82.0         0.0000
# 4848                102            clear-day         20.0         0.0000
# 4059                  0  partly-cloudy-night         37.0         0.0000
#
#              lat       long                 events  \
# ...

# %% [markdown]
# ## 1)Filter the data to include only weekdays (Monday to Friday) and plot a line graph showing the pedestrian counts for each day of the week.

# %%
weekdays = bridge_df[(bridge_df['hour_beginning'].dt.dayofweek >= 0) & (bridge_df['hour_beginning'].dt.dayofweek) <= 4]

# %%
weekdays
# Out:
#            hour_beginning         location  Pedestrians  Towards Manhattan  \
# 0     2019-04-30 00:00:00  Brooklyn Bridge            3                  3
# 1     2019-12-31 22:00:00  Brooklyn Bridge           10                  9
# 2     2019-12-31 23:00:00  Brooklyn Bridge            2                  0
# 3     2019-12-31 21:00:00  Brooklyn Bridge           12                  0
# 4     2019-04-01 03:00:00  Brooklyn Bridge            1                  0
# ...                   ...              ...          ...                ...
# 16052 2018-06-22 04:00:00  Brooklyn Bridge            7                  4
# 16053 2018-07-19 06:00:00  Brooklyn Bridge          192                 89
# 16054 2018-06-16 16:00:00  Brooklyn Bridge         2623               1161
# 16055 2018-07-24 18:00:00  Brooklyn Bridge         2016               1069
# 16056 2018-07-23 00:00:00  Brooklyn Bridge           57                 20
#
# ...

# %%
countperday = weekdays.groupby(weekdays['hour_beginning'].dt.day_name())['Pedestrians'].sum()

# %%
countperday
# Out:
# hour_beginning
# Friday       1588068
# Monday       1481435
# Saturday     2150464
# Sunday       1736156
# Thursday     1370880
# Tuesday      1394963
# Wednesday    1310900
# Name: Pedestrians, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.plot(countperday)
plt.title('Pedestrian Counts for Each Day of the Week')
plt.xlabel('Day of Week')
plt.ylabel('no. of Pedestrians')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2) Track pedestrian counts on the Brooklyn Bridge for the year 2019 and analyze how different weather conditions influence pedestrian activity in that year. Sort the pedestrian count data by weather summary to identify any correlations( with a correlation matrix) between weather patterns and pedestrian counts for the selected year.

# %%
bridge_2019 = bridge_df[(bridge_df['location'] == 'Brooklyn Bridge') & (bridge_df['hour_beginning'].dt.year == 2019)]
weather_summary_encoded = pd.get_dummies(bridge_2019['weather_summary'])



# Concatenate encoded weather summary with pedestrian counts
encoded_data = pd.concat([weather_summary_encoded, bridge_2019['Pedestrians']], axis=1)

# Calculate correlation matrix
correlation_matrix = encoded_data.corr()

# Plot correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Weather Summary and Pedestrian Counts')
plt.show()

# %% [markdown]
# ## 3)Implement a custom function to categorize time of day into morning, afternoon, evening, and night, and create a new column in the DataFrame to store these categories. Use this new column to analyze pedestrian activity patterns throughout the day.

# %%
# Custom function to categorize time of day (Intervals can be chosen according to your liking)
def categorize_time_of_day(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 24:
        return 'Evening'
    else:
        return 'Night'

# Create new column to store time of day categories
bridge_df['time_of_day'] = bridge_df['hour_beginning'].dt.hour.apply(categorize_time_of_day)

# Aggregating pedestrian count throughout the day
ped_counts_per_time_of_day = bridge_df.groupby('time_of_day')['Pedestrians'].sum()

print("Pedestrian Activity Patterns Throughout the Day:")
print(ped_counts_per_time_of_day)
# Out:
# Pedestrian Activity Patterns Throughout the Day:
# time_of_day
# Afternoon    6803093
# Evening      1710794
# Morning      2466776
# Night          52203
# Name: Pedestrians, dtype: int64
